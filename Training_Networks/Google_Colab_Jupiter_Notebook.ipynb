# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from torchvision import models
from summary import summary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-992cee1a8e5e> in <module>()
#       1 from torchvision import models
# ----> 2 from summary import summary
#
# ModuleNotFoundError: No module named 'summary'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#log in to project
from google.colab import auth
auth.authenticate_user()
project_id = 'mpiigaze'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud alpha survey

# %%
#copy to bucket
bucket_name = 'mpiigaze'
# !gsutil -m cp -r /content/drive/My\ Drive/colab/alexa.txt gs://{bucket_name}/

# %%
#https://medium.com/@oribarel/getting-the-most-out-of-your-google-colab-2b0585f82403
# !python -u /content/drive/My\ Drive/colab/main_zhang.py --arch zhang --dataset /content/drive/My\ Drive/colab/data --test_id 0 --outdir /content/drive/My\ Drive/colab/results/zhang/00 --batch_size 32 --base_lr 0.01 --momentum 0.9 --nesterov True --weight_decay 0.0005 --epochs 60 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard

# %%
#!python -u /content/drive/My\ Drive/colab/main.py --arch resnet_preact --dataset /content/drive/My\ Drive/colab/data --test_id 0 --outdir /content/drive/My\ Drive/colab/results/resnet_preact/00 --batch_size 32 --base_lr 0.1 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 60 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard
# !python -u /content/drive/My\ Drive/colab/main.py --arch myresnet_basic --dataset /content/drive/My\ Drive/colab/data --test_id 0 --outdir /content/drive/My\ Drive/colab/results/resnet_preact/00 --batch_size 32 --base_lr 0.1 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 60 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard

# %%
# classic resnet-6
# !python -u /content/drive/My\ Drive/colab/main_resnet18.py --arch myresnet_basic --dataset /content/drive/My\ Drive/colab/data --test_id 0 --outdir /content/drive/My\ Drive/colab/results/resnet18/00 --batch_size 32 --base_lr 0.1 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 60 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard

# %%
# cross dataset. Train UT_Multiview. Test MPIIGaze
# !pip install tensorboardX
from tensorboardX import SummaryWriter
from google.colab import drive
#!python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset data  --outdir results/myresnet/00 --batch_size 32 --base_lr 0.001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 40 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard..........................................................................................................................................per_person_mpiigaze, person_specific
#!python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 40 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 0 --fold 4
# Out:
# ...
#      |████████████████████████████████| 204kB 3.3MB/s
# ...

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset uperdata --testset uperdata  --outdir results/resnet_preact/00 --batch_size 32 --base_lr 0.0001 --momentum 0.5 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type per_person_mpiigaze --personID 5 --fold 0

# %%
# !pip install tensorboardX
# !pip install summaryWriter
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset data  --outdir results/cross_dataset --batch_size 32 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 50 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type cross_dataset --personID 9 --fold 0
# Out:
# ...
#      |████████████████████████████████| 204kB 48.0MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement summaryWriter (from versions: none)
# ERROR: No matching distribution found for summaryWriter
# [2020/02/13 21:57:27 __main__ INFO] - {
#   "arch": "myresnet_basic",
#   "dataset": "data_UT_Multiview",
#   "test_id": null,
#   "testset": "data",
#   "outdir": "results/cross_dataset",
#   "seed": 17,
#   "resnet_type": "basic",
#   "gate_kernel": 7,
#   "ff1_out": 512,
#   "ff2_out": 512,
#   "block_type": "basic",
#   "block_sizes": [
#     64,
#     128,
#     256,
#     512
#   ],
#   "deepths": [
#     2,
#     2,
#     2,
#     2
#   ],
#   "numOfFC": 3,
#   "valid_type": "cross_dataset",
#   "personID": 9,
#   "fold": 0,
#   "epochs": 50,
#   "batch_size": 32,
#   "base_lr": 0.0001,
#   "weight_decay": 0.0001,
#   "momentum": 0.9,
#   "nesterov": true,
#   "milestones": [
#     30,
#     35
#   ],
#   "lr_decay": 0.1,
#   "num_workers": 7,
# ...

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 6 --fold 2

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 6 --fold 3

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 6 --fold 4

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 7 --fold 0

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 7 --fold 1

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 7 --fold 2

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 7 --fold 3

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 7 --fold 4

# %%
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview --testset uperdata  --outdir results/resnet_preact/00 --batch_size 4 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 30 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type basic --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type person_specific --personID 8 --fold 0
# Out:
# python3: can't open file 'main_resnet18.py': [Errno 2] No such file or directory

# %%
# per participant. Train UT_Multiview. Test MPIIGaze(one person only)
#
#
#
# !pwd
# !python -u main_resnet18.py --arch myresnet_basic --dataset data_UT_Multiview/ --testset data  --outdir results/cross_data_bottle --batch_size 32 --base_lr 0.0001 --momentum 0.9 --nesterov True --weight_decay 1e-4 --epochs 50 --milestones '[30, 35]' --lr_decay 0.1 --tensorboard --gate_kernel 7 --numOfFC 3 --ff1_out 512 --ff2_out 512 --block_type bottle --block_sizes 64 128 256 512   --deepths 2 2 2 2  --resnet_type basic --valid_type cross_dataset --personID 14 --fold 0
# Out:
# /content/drive/My Drive/colab
# [2020/02/18 12:15:10 __main__ INFO] - {
#   "arch": "myresnet_basic",
#   "dataset": "data_UT_Multiview/",
#   "test_id": null,
#   "testset": "data",
#   "outdir": "results/cross_data_bottle",
#   "seed": 17,
#   "resnet_type": "basic",
#   "gate_kernel": 7,
#   "ff1_out": 512,
#   "ff2_out": 512,
#   "block_type": "bottle",
#   "block_sizes": [
#     64,
#     128,
#     256,
#     512
#   ],
#   "deepths": [
#     2,
#     2,
#     2,
#     2
#   ],
#   "numOfFC": 3,
#   "valid_type": "cross_dataset",
#   "personID": 14,
#   "fold": 0,
#   "epochs": 50,
#   "batch_size": 32,
#   "base_lr": 0.0001,
#   "weight_decay": 0.0001,
#   "momentum": 0.9,
#   "nesterov": true,
#   "milestones": [
#     30,
#     35
#   ],
#   "lr_decay": 0.1,
#   "num_workers": 7,
#   "tensorboard": true,
#   "tensorboard_images": false,
#   "tensorboard_parameters": false
# }
# ResNetEncoder(
#   (gate): Sequential(
# ...

# %%
import torch
import torch.nn as nn
from functools import partial
import importlib

module = importlib.import_module('models.myresnet_basic')
model = module.Model()

img = torch.rand(1,1,60,36)
pose = torch.rand(1,2)
#model = resnet18(in_channels=1, n_outputs=2,block=ResNetBasicBlock)
from torchsummary import summary
input=(img,pose)
summary(model,[(1,1,60,36),(1,2)])#summary(model.cuda(), (3, 224, 224))
#print(model)
### etoimi ulopoihsh ###
#import torchvision.models as models
#summary(models.resnet18(False), (3, 224, 224))

# %%
import torch
import torch.nn as nn
from functools import partial
import importlib

m = nn.AdaptiveMaxPool2d((1,1))
input = torch.randn(1, 64, 8, 9)
output = m(input)
print(output.shape)
# Out:
# torch.Size([1, 64, 1, 1])

# %%
#tensorboard --logdir=name1:/path/to/logs/1,name2:/path/to/logs/2
#!tensorboard --version
#!tensorboard --logdir /content/drive/My\ Drive/colab/runs
#!pip install -q tf-nightly-2.0-preview
# Load the TensorBoard notebook extension
#!kill 6006
# %reload_ext tensorboard
import os
os.chdir("/content/drive/My Drive/colab/")
# %tensorboard --logdir best_runs
#!ngrok http 6006
#!tensorboard --logdir runs --host 0.0.0.0 #--port 6006

# %%
#### I lush edw einai:https://stackoverflow.com/questions/47818822/can-i-use-tensorboard-with-google-colab
#Get TensorBoard running in the background.
#runs/Jul21_10-50-45_793adf6a18d5
#%reload_ext tensorboard


#You must erase Tensorboard's log files AND kill its process
#!kill $(lsof -t -i:6006) #!fuser 6006/tcp -k
import os
os.chdir("/content/drive/My Drive/colab/")
#%load_ext tensorboard
#!kill 6006
LOG_DIR = 'best_runs/'
get_ipython().system_raw(
    'tensorboard --logdir best_runs --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
#! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip# Replace the link passed to wget with the correct download link for your OS.
#! unzip ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 6006 &')#Launch ngrok background process...

# Tunnel port 6006 (TensorBoard assumed running)
#get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')
# Get url
#! cat url.txt

! curl  -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
# !pip install tensorboardX
# !pip install summaryWriter
# !ls
# Out:
# ...
#      |████████████████████████████████| 204kB 48.5MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement summaryWriter (from versions: none)
# ERROR: No matching distribution found for summaryWriter
# drive  sample_data

# %%
# !tensorboard --logdir /content/drive/My\ Drive/colab/runs
# Out:
# TensorBoard 1.14.0 at http://e9fce6ca0807:6007/ (Press CTRL+C to quit)
# ^C

# %%
tensorboard /content/drive/My\ Drive/colab/results/resnet_preact/00/all_scalars.json

# %%
import os
os.chdir("/content/drive/My Drive/colab")
#!rm main*.py
#!rm main_resnet18.py
#!rm *.pyc
# !ls
# Out:
#  alexa.txt			  ngrok-stable-linux-amd64.zip.2
#  best_runs			  ngrok-stable-linux-amd64.zip.3
# 'Copy of dataloader.py'		  ngrok-stable-linux-amd64.zip.4
# 'Copy of main_resnet18.py'	  ngrok-stable-linux-amd64.zip.5
#  data				  ngrok-stable-linux-amd64.zip.6
#  dataloader.py			  ngrok-stable-linux-amd64.zip.7
#  data_UT_Multiview		  ngrok-stable-linux-amd64.zip.8
#  main.py			  ngrok-stable-linux-amd64.zip.9
#  main_resnet18.py		  ORIGmain_resnet18.py
#  main_zhang.py			  __pycache__
#  models				  results
#  model_state.pt			  runs
#  multimain.py			 'Thesis(3).zip'
#  newdata			  thesis.ipynb
#  ngrok				  uperdata
#  ngrok-stable-linux-amd64.zip	  url.txt
#  ngrok-stable-linux-amd64.zip.1

# %%
#!rm /content/drive/My Drive/colab/models/zhang*
# !ls models
# Out:
# lenet.py  myresnet_basic.py  __pycache__  resnet_preact.py  zhang.py
